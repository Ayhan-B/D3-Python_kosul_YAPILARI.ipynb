# %%
print("Merhaba, İGÜ - İSTKA / Ders 4") # print ekrana çıktı veren bir koddur.


import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)


from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')


import os

os.chdir('/content/drive/My Drive/COLAB_DERSKLASORU')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.

# %%
#if Koşul yapısı

x=10
if x>5:
  print("x,5'ten büyüktür.")
# Out:
# x,5'ten büyüktür.

# %%
#if-else koşulu yapısı

x=3

if x>5:
  print("x,5'ten büyüktür.")
else :
  print("x,5'dan küçük veya eşittir.")
# Out:
# x,5'dan küçük veya eşittir.

# %%
# if-elif-else koşul yapısı

x=8

if x>10:
  print("x,10'dan büyüktür.")
elif x>5:
  print("x,5'ten büyüktür ama 10'dan küçük veya eşittir.")
else:
  print("x,5'ten küçük veya eşittir.")
# Out:
# x,5'ten büyüktür ama 10'dan küçük veya eşittir.

# %%
# iç içe Koşul yapısı

x=12
y=8

if x>10:
  if y>5:
    print("x,10'dan büyüktür ve y,5'ten büyüktür.")  # Bu satır çalışır.
  else:
    print("x,10'dan büyük ama y,5'ten küçük veya eşittir.")
else:
  print("x,10'dan küçük veya eşittir.")
# Out:
# x,10'dan büyüktür ve y,5'ten büyüktür.

# %%
#Mantıksal operatörler  ile Koşullar

x=7
Y=3

# 'and' operatörü ile
if x> 5 and y>2:
  print("x,5'ten büyüktür ve y,2'den büyüktür.") # Bu satır çalışır

  # 'or' operatörü ile
if x> 5 or y>2:
  print("x veya y,5'ten büyüktür.") # Bu satır çalışır

  # 'not' operatörü ile
if not (x> 10):
  print("x,10'dan büyük değildir.") # Bu satır çalışır
# Out:
# x,5'ten büyüktür ve y,2'den büyüktür.
# x veya y,5'ten büyüktür.
# x,10'dan büyük değildir.

# %%
# Örnek 1: Not Sistemi

notu = 85 #not farkını gösterilecek...

if notu >= 90:
    print("Harf notu: A")
elif notu >= 80:
    print("Harf notu: B")  # Bu satır çalışır
elif notu >= 70:
    print("Harf notu: C")
elif notu >= 60:
    print("Harf notu: D")
else:
    print("Harf notu: F")
# Out:
# Harf notu: B

# %%
# Örnek 2 : yaş kontrolü

yas = 20

if yas <= 18:
    print("Reşit değilsiniz.")
elif yas <= 21:
    print("Reşitsiniz ama içecek satın alamazsınız.")
else:
    print("içecek satın alabilirsiniz.")
# Out:
# Reşitsiniz ama içecek satın alamazsınız.

# %%
#Örnek 3:sayı pozitif ,Negatif veya Sıfır mı?
sayı=-5
if sayı > 0:
    print("Sayı pozitiftir.")
elif sayı < 0:
    print("Sayı negatiftir.")  # Bu satır çalışır
else:
    print("Sayı sıfırdır.")
# Out:
# Sayı negatiftir.
